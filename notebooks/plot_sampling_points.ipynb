# %%
# !pip install geopandas
# !pip install geodatasets
# Out:
# Requirement already satisfied: geopandas in c:\users\marle\miniconda3\envs\mila\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from geopandas) (1.26.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from geopandas) (2.2.0)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: certifi in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Collecting geodatasets
#   Downloading geodatasets-2024.8.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting pooch (from geodatasets)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from pooch->geodatasets) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from pooch->geodatasets) (23.2)
# Collecting requests>=2.19.0 (from pooch->geodatasets)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch->geodatasets)
#   Using cached charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch->geodatasets)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch->geodatasets)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marle\miniconda3\envs\mila\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2024.2.2)
# Downloading geodatasets-2024.8.0-py3-none-any.whl (20 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 1.7 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.0-cp310-cp310-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, requests, pooch, geodatasets
# Successfully installed charset-normalizer-3.4.0 geodatasets-2024.8.0 idna-3.10 pooch-1.8.2 requests-2.32.3 urllib3-2.2.3

# %%
import geodatasets
import geopandas as gpd
import pandas as pd
from geopandas import GeoDataFrame
from shapely.geometry import Point

df = pd.read_csv(
    "../data/pretraining_points/sampling_points_mountains.csv",
    delimiter=",",
    skiprows=0,
    low_memory=False,
)

geometry = [Point(xy) for xy in zip(df["Longitude"], df["Latitude"])]
gdf = GeoDataFrame(df, geometry=geometry)

# this is a simple map that goes with geopandas
# deprecated: world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world = gpd.read_file(geodatasets.data.naturalearth.land["url"])
gdf.plot(ax=world.plot(figsize=(10, 6)), marker="o", color="red", markersize=15);
